# %% [markdown]
# # Standard Normal Distribution - Lab
#
# ## Introduction
#
# In the previous lesson, we looked at the formula and a few toy examples to explain an observation's standard score and data standardization for normally distributed data. This lab, will shall standardize and visualize some normal distributions before we see standardization's real impact in machine learning in upcoming lessons.
#
# ## Objectives
#
# You will be able to:
#
# * Calculate and interpret z-scores for observations
# * Visualize the data before-after standardization to visually inspect the results.
#
# ## Let's get started
#
# > A Z-score tells us “how many standard deviations above or below the mean.” Every time you obtain a Z-score, use “above” or “below” in your phrasing.

# %% [markdown]
# The yields of apples trees in an orchard has been recorded in the file `yield.csv`. Each observation is recorded by weighing apples from trees (in pounds) and adding their weights. There are 5000 observations in total for this data.
#
# **1. Load, visualize and give general comments on the dataset. Use pandas for loading and inspecting the data.**

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
# %matplotlib inline

# Read the yield data as a dataframe
data = pd.read_csv('yield.csv')

# %%
# Your comments about the data here. 
print(data.shape)
print(data.head())
print('-------')
print(data.mean())
print(data.median())
data.describe()
data.plot()
# Out:
# (5000, 1)
#            0
# 0  39.741234
# 1  39.872055
# 2  44.331164
# 3  46.600623
# 4  40.694984
# -------
# 0    42.407624
# dtype: float64
# 0    42.352304
# dtype: float64

# %% [markdown]
# **2. Write a simple sentence to explain what does each value represent in this data?**

# %%
# Your answer here
# Each value is the yield (in pounds) of a given apple tree at an 
# orchard

# %% [markdown]
# **3. What does the 3-sigma rule say about yields of trees ?**

# %%
# Perform any calculations necessary here
norm_data = [(x - data.mean())/data.std() for x in data['0']]

# %%
mean
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-6-18a976ba6deb> in <module>()
# ----> 1 mean
#
# NameError: name 'mean' is not defined

# %%
mean = data.mean()
sd = data.std()
mean,sd
# Out:
# (0    42.407624
#  dtype: float64, 0    6.003697
#  dtype: float64)

# %%
print(mean-sd,mean+sd)
print('==========')
print(mean-2*sd,mean+2*sd)
print('----------')
print(mean-3*sd,mean+3*sd)
# Out:
# 0    36.403927
# dtype: float64 0    48.41132
# dtype: float64
# ==========
# 0    30.400231
# dtype: float64 0    54.415017
# dtype: float64
# ----------
# 0    24.396534
# dtype: float64 0    60.418713
# dtype: float64

# %%
plt.plot(norm_data)

# %%
# Write your answer here

# %% [markdown]
# **4. Compute the Z-score for a tree yielding 35 pounds of apples. Interpret this Z-score.**

# %%
# Calculate z
(35-mean)/sd
# Out:
# 0   -1.233844
# dtype: float64

# %%
# Interpret the result
# A little over one standard deviation below avg

# %% [markdown]
# **5. Suppose a tree has a Z-score of 1.85. Interpret this Z-score. What is the yield of this tree?**

# %%
# Interpret the z score
# 1.85 = (x-mean)/sd
# This is a fruitful tree

# %%
1.85*sd+mean
# Out:
# 0    53.514462
# dtype: float64

# %%
# Calculate yield

# %%
# What is the yield ?

# %% [markdown]
# **6. Convert each tree’s yield is converted to a Z-score so that “new” derived variable is “Z-score for weight”. The units are still the apple trees. For the data set of all Z-scores:**
# * What is the shape?
# * The mean?
# * The standard deviation?

# %%
norm_data = [(x - data.mean())/data.std() for x in data['0']]
newdf = (data - mean)/sd

# %%
newdf
# Out:
#              0
# 0    -0.444125
# 1    -0.422335
# 2     0.320393
# 3     0.698403
# 4    -0.285264
# 5    -0.239487
# 6     1.094906
# 7     0.138668
# 8     0.648659
# 9     0.495257
# 10   -0.811946
# 11    0.928692
# 12    0.534435
# 13   -0.392084
# 14    0.028308
# 15   -0.478906
# 16    0.356123
# 17   -0.832941
# 18   -1.175393
# 19    1.279213
# 20    0.909671
# 21   -0.374599
# 22   -0.793687
# 23    0.711617
# 24   -0.861522
# 25    1.066177
# 26   -0.667751
# 27    0.312444
# 28    1.049815
# 29    0.043299
# ...        ...
# 4970 -0.383577
# 4971 -0.093924
# 4972  0.220139
# 4973 -0.844333
# 4974  1.666715
# 4975 -0.180472
# 4976 -2.010264
# 4977  0.471804
# 4978  0.904203
# 4979 -1.302588
# 4980  0.960468
# 4981 -0.460034
# 4982 -0.016542
# 4983  0.586477
# 4984 -0.954641
# 4985 -1.219308
# 4986 -1.135474
# 4987 -0.458902
# 4988 -0.035382
# 4989 -1.411812
# 4990  0.415118
# 4991 -0.814562
# 4992  0.797660
# 4993 -1.015009
# 4994 -0.648765
# 4995 -0.561300
# 4996  1.574607
# 4997 -0.993766
# 4998  0.023595
# 4999 -1.267422
#
# [5000 rows x 1 columns]

# %%
import seaborn as sns

# %%
norm_data
# Out:
# [0   -0.444125
#  dtype: float64, 0   -0.422335
#  dtype: float64, 0    0.320393
#  dtype: float64, 0    0.698403
#  dtype: float64, 0   -0.285264
#  dtype: float64, 0   -0.239487
#  dtype: float64, 0    1.094906
#  dtype: float64, 0    0.138668
#  dtype: float64, 0    0.648659
#  dtype: float64, 0    0.495257
#  dtype: float64, 0   -0.811946
#  dtype: float64, 0    0.928692
#  dtype: float64, 0    0.534435
#  dtype: float64, 0   -0.392084
#  dtype: float64, 0    0.028308
#  dtype: float64, 0   -0.478906
#  dtype: float64, 0    0.356123
#  dtype: float64, 0   -0.832941
#  dtype: float64, 0   -1.175393
#  dtype: float64, 0    1.279213
#  dtype: float64, 0    0.909671
#  dtype: float64, 0   -0.374599
#  dtype: float64, 0   -0.793687
#  dtype: float64, 0    0.711617
#  dtype: float64, 0   -0.861522
#  dtype: float64, 0    1.066177
#  dtype: float64, 0   -0.667751
#  dtype: float64, 0    0.312444
#  dtype: float64, 0    1.049815
#  dtype: float64, 0    0.043299
#  dtype: float64, 0   -0.193309
#  dtype: float64, 0    1.163291
#  dtype: float64, 0    0.153705
#  dtype: float64, 0   -1.082564
#  dtype: float64, 0    1.312151
#  dtype: float64, 0   -0.117248
#  dtype: float64, 0    0.95781
#  dtype: float64, 0    1.605453
#  dtype: float64, 0   -0.664026
#  dtype: float64, 0   -1.007268
#  dtype: float64, 0    0.232709
#  dtype: float64, 0   -1.535553
#  dtype: float64, 0    1.993581
#  dtype: float64, 0    0.483099
#  dtype: float64, 0   -0.649096
#  dtype: float64, 0    2.287038
#  dtype: float64, 0    0.397927
#  dtype: float64, 0   -0.568762
#  dtype: float64, 0   -0.067645
#  dtype: float64, 0   -1.167859
#  dtype: float64, 0   -0.393509
#  dtype: float64, 0   -0.366335
#  dtype: float64, 0   -0.648065
#  dtype: float64, 0   -0.835536
#  dtype: float64, 0    1.533867
#  dtype: float64, 0    1.157126
#  dtype: float64, 0    0.401587
#  dtype: float64, 0   -0.023119
#  dtype: float64, 0   -0.135247
#  dtype: float64, 0    1.859596
#  dtype: float64, 0   -0.413667
#  dtype: float64, 0    1.93129
#  dtype: float64, 0   -0.880034
#  dtype: float64, 0   -0.793318
#  dtype: float64, 0    0.766018
#  dtype: float64, 0   -0.816378
#  dtype: float64, 0   -0.400005
#  dtype: float64, 0    0.710339
#  dtype: float64, 0   -0.632073
#  dtype: float64, 0   -0.084707
#  dtype: float64, 0   -2.292413
#  dtype: float64, 0   -1.893262
#  dtype: float64, 0   -2.247301
#  dtype: float64, 0    1.493248
#  dtype: float64, 0   -0.423068
#  dtype: float64, 0   -0.665189
#  dtype: float64, 0    1.202763
#  dtype: float64, 0   -0.25178
#  dtype: float64, 0    1.628306
#  dtype: float64, 0    0.012941
#  dtype: float64, 0   -0.102397
#  dtype: float64, 0   -0.651305
#  dtype: float64, 0   -0.656201
#  dtype: float64, 0   -0.015936
#  dtype: float64, 0   -0.072644
#  dtype: float64, 0   -1.129917
#  dtype: float64, 0    0.015396
#  dtype: float64, 0   -1.210874
#  dtype: float64, 0   -0.913941
#  dtype: float64, 0   -0.171324
#  dtype: float64, 0   -0.97173
#  dtype: float64, 0   -0.30249
#  dtype: float64, 0   -1.944061
#  dtype: float64, 0   -0.754446
#  dtype: float64, 0    0.085126
#  dtype: float64, 0    0.835696
#  dtype: float64, 0   -1.14838
#  dtype: float64, 0   -1.331085
#  dtype: float64, 0   -0.836888
#  dtype: float64, 0    0.741333
#  dtype: float64, 0    0.634639
#  dtype: float64, 0   -0.186812
#  dtype: float64, 0   -0.075347
#  dtype: float64, 0    1.194269
#  dtype: float64, 0    1.41207
#  dtype: float64, 0   -0.705919
#  dtype: float64, 0   -0.228112
#  dtype: float64, 0    1.814588
#  dtype: float64, 0    0.079794
#  dtype: float64, 0   -0.777087
#  dtype: float64, 0   -0.430968
#  dtype: float64, 0    0.746872
#  dtype: float64, 0   -0.887213
#  dtype: float64, 0   -0.288362
#  dtype: float64, 0    1.376974
#  dtype: float64, 0    0.093367
#  dtype: float64, 0    0.899961
#  dtype: float64, 0   -0.658337
#  dtype: float64, 0    1.318892
#  dtype: float64, 0   -0.13773
#  dtype: float64, 0   -0.658125
#  dtype: float64, 0   -1.53582
#  dtype: float64, 0   -1.703618
#  dtype: float64, 0    0.448644
#  dtype: float64, 0    1.697692
#  dtype: float64, 0    0.566426
#  dtype: float64, 0   -1.222277
#  dtype: float64, 0   -0.261732
#  dtype: float64, 0   -1.886252
#  dtype: float64, 0   -0.1359
#  dtype: float64, 0   -0.055587
#  dtype: float64, 0    0.182281
#  dtype: float64, 0    1.414605
#  dtype: float64, 0    0.644155
#  dtype: float64, 0   -1.208887
#  dtype: float64, 0    0.678938
#  dtype: float64, 0    1.957477
#  dtype: float64, 0   -0.146295
#  dtype: float64, 0   -0.574413
#  dtype: float64, 0    0.838575
#  dtype: float64, 0    1.684395
#  dtype: float64, 0   -0.317902
#  dtype: float64, 0    0.934374
#  dtype: float64, 0    0.20628
#  dtype: float64, 0   -0.400957
#  dtype: float64, 0    0.819835
#  dtype: float64, 0    0.635917
#  dtype: float64, 0    0.012097
#  dtype: float64, 0   -0.226254
#  dtype: float64, 0    0.033939
#  dtype: float64, 0    1.034735
#  dtype: float64, 0   -0.926253
#  dtype: float64, 0    0.826212
#  dtype: float64, 0   -0.483947
#  dtype: float64, 0    0.103317
#  dtype: float64, 0   -1.82607
#  dtype: float64, 0    0.067904
#  dtype: float64, 0    1.574131
#  dtype: float64, 0    1.146619
#  dtype: float64, 0   -1.572866
#  dtype: float64, 0   -0.495551
#  dtype: float64, 0   -1.396944
#  dtype: float64, 0   -0.904576
#  dtype: float64, 0   -1.082933
#  dtype: float64, 0    1.345689
#  dtype: float64, 0   -0.574506
#  dtype: float64, 0   -0.147384
#  dtype: float64, 0   -2.339874
#  dtype: float64, 0    0.101481
#  dtype: float64, 0    2.717028
#  dtype: float64, 0   -0.793412
#  dtype: float64, 0   -1.264337
#  dtype: float64, 0   -0.370798
#  dtype: float64, 0    2.606812
#  dtype: float64, 0   -0.837736
#  dtype: float64, 0   -0.189445
#  dtype: float64, 0    2.252405
#  dtype: float64, 0    0.595533
#  dtype: float64, 0   -0.911143
#  dtype: float64, 0    0.146946
#  dtype: float64, 0   -1.346972
#  dtype: float64, 0    1.10046
#  dtype: float64, 0    0.282484
#  dtype: float64, 0   -0.010979
#  dtype: float64, 0   -0.264913
#  dtype: float64, 0   -0.716693
#  dtype: float64, 0   -0.344121
#  dtype: float64, 0   -0.844572
#  dtype: float64, 0   -0.331018
#  dtype: float64, 0    0.278969
#  dtype: float64, 0   -1.872367
#  dtype: float64, 0   -0.485303
#  dtype: float64, 0    0.133253
#  dtype: float64, 0    0.24882
#  dtype: float64, 0    0.349041
#  dtype: float64, 0    0.189976
#  dtype: float64, 0    1.280109
#  dtype: float64, 0    0.888009
#  dtype: float64, 0    1.052733
#  dtype: float64, 0   -0.723289
#  dtype: float64, 0    1.02199
#  dtype: float64, 0   -1.117478
#  dtype: float64, 0   -1.662686
#  dtype: float64, 0    0.995917
#  dtype: float64, 0    0.638682
#  dtype: float64, 0   -1.349918
#  dtype: float64, 0    1.004902
#  dtype: float64, 0   -0.473196
#  dtype: float64, 0   -0.299259
#  dtype: float64, 0   -0.86148
#  dtype: float64, 0    1.688192
#  dtype: float64, 0   -0.334023
#  dtype: float64, 0   -0.183287
#  dtype: float64, 0    1.172631
#  dtype: float64, 0   -1.77404
#  dtype: float64, 0    1.513148
#  dtype: float64, 0    0.405162
#  dtype: float64, 0   -0.083553
#  dtype: float64, 0    0.30942
#  dtype: float64, 0   -0.205364
#  dtype: float64, 0   -0.009481
#  dtype: float64, 0   -0.491177
#  dtype: float64, 0    0.058996
#  dtype: float64, 0   -0.996485
#  dtype: float64, 0    0.305326
#  dtype: float64, 0   -1.804066
#  dtype: float64, 0   -1.112624
#  dtype: float64, 0    2.286724
#  dtype: float64, 0   -1.581883
#  dtype: float64, 0    0.299616
#  dtype: float64, 0   -0.696399
#  dtype: float64, 0   -0.569677
#  dtype: float64, 0   -0.254993
#  dtype: float64, 0   -0.866987
#  dtype: float64, 0   -0.978147
#  dtype: float64, 0    1.033531
#  dtype: float64, 0   -1.271027
#  dtype: float64, 0    1.422283
#  dtype: float64, 0    0.564717
#  dtype: float64, 0   -0.029315
#  dtype: float64, 0   -1.719796
#  dtype: float64, 0    0.224034
#  dtype: float64, 0    0.439244
#  dtype: float64, 0    0.933982
#  dtype: float64, 0    0.123179
#  dtype: float64, 0    0.507952
#  dtype: float64, 0   -0.995158
#  dtype: float64, 0    1.631871
#  dtype: float64, 0    0.55396
#  dtype: float64, 0   -0.836574
#  dtype: float64, 0    1.319835
#  dtype: float64, 0    0.642558
#  dtype: float64, 0    0.125642
#  dtype: float64, 0   -2.035804
#  dtype: float64, 0   -0.271167
#  dtype: float64, 0    1.187195
#  dtype: float64, 0   -2.094228
#  dtype: float64, 0   -0.74425
#  dtype: float64, 0    0.776007
#  dtype: float64, 0    0.005497
#  dtype: float64, 0   -1.063291
#  dtype: float64, 0   -1.031097
#  dtype: float64, 0    0.458017
#  dtype: float64, 0    0.285151
#  dtype: float64, 0   -0.496471
#  dtype: float64, 0    0.98618
#  dtype: float64, 0   -0.080652
#  dtype: float64, 0   -0.877233
#  dtype: float64, 0   -0.622168
#  dtype: float64, 0    1.59218
#  dtype: float64, 0    0.247862
#  dtype: float64, 0   -0.197772
#  dtype: float64, 0   -3.139651
#  dtype: float64, 0   -0.653658
#  dtype: float64, 0   -1.352108
#  dtype: float64, 0   -1.612597
#  dtype: float64, 0   -0.164202
#  dtype: float64, 0   -1.152857
#  dtype: float64, 0   -0.453817
#  dtype: float64, 0   -1.701171
#  dtype: float64, 0   -0.213191
#  dtype: float64, 0   -0.118197
#  dtype: float64, 0    1.128236
#  dtype: float64, 0    1.152982
#  dtype: float64, 0   -0.226188
#  dtype: float64, 0   -1.055791
#  dtype: float64, 0   -1.677893
#  dtype: float64, 0    0.796215
#  dtype: float64, 0    1.474199
#  dtype: float64, 0    1.819744
#  dtype: float64, 0    0.558895
#  dtype: float64, 0   -0.011245
#  dtype: float64, 0    0.567326
#  dtype: float64, 0    1.049409
#  dtype: float64, 0   -1.599907
#  dtype: float64, 0    0.173103
#  dtype: float64, 0   -0.361895
#  dtype: float64, 0   -0.874601
#  dtype: float64, 0    0.633018
#  dtype: float64, 0   -0.075151
#  dtype: float64, 0    0.215821
#  dtype: float64, 0    0.518755
#  dtype: float64, 0   -0.450791
#  dtype: float64, 0    0.288489
#  dtype: float64, 0   -1.097758
#  dtype: float64, 0    0.633505
#  dtype: float64, 0    0.430558
#  dtype: float64, 0    0.668003
#  dtype: float64, 0   -2.010827
#  dtype: float64, 0   -0.166537
#  dtype: float64, 0   -0.91517
#  dtype: float64, 0   -0.833384
#  dtype: float64, 0    1.978642
#  dtype: float64, 0   -1.191286
#  dtype: float64, 0   -0.297172
#  dtype: float64, 0    0.453256
#  dtype: float64, 0   -0.732096
#  dtype: float64, 0   -0.54928
#  dtype: float64, 0   -1.157837
#  dtype: float64, 0    1.05167
#  dtype: float64, 0   -0.489748
#  dtype: float64, 0    0.546069
#  dtype: float64, 0   -1.281022
#  dtype: float64, 0    2.594458
#  dtype: float64, 0   -1.104
#  dtype: float64, 0    0.9709
#  dtype: float64, 0   -1.887623
#  dtype: float64, 0   -0.801888
#  dtype: float64, 0    0.924933
#  dtype: float64, 0    0.665473
#  dtype: float64, 0   -1.844545
#  dtype: float64, 0    0.402006
#  dtype: float64, 0   -1.715842
#  dtype: float64, 0    0.680414
#  dtype: float64, 0   -1.146744
#  dtype: float64, 0   -2.41572
#  dtype: float64, 0    0.586425
#  dtype: float64, 0   -0.370246
#  dtype: float64, 0    0.509925
#  dtype: float64, 0    0.379392
#  dtype: float64, 0   -1.388717
#  dtype: float64, 0    0.249902
#  dtype: float64, 0   -0.19426
#  dtype: float64, 0   -0.301773
#  dtype: float64, 0    0.992898
#  dtype: float64, 0    0.068226
#  dtype: float64, 0   -0.358123
#  dtype: float64, 0    0.547978
#  dtype: float64, 0   -0.770819
#  dtype: float64, 0    0.91525
#  dtype: float64, 0    0.124648
#  dtype: float64, 0   -0.092001
#  dtype: float64, 0    1.202295
#  dtype: float64, 0   -0.857465
#  dtype: float64, 0   -0.887035
#  dtype: float64, 0   -0.584684
#  dtype: float64, 0    0.324749
#  dtype: float64, 0   -0.073318
#  dtype: float64, 0    0.767607
#  dtype: float64, 0    0.444768
#  dtype: float64, 0   -0.492885
#  dtype: float64, 0   -0.261821
#  dtype: float64, 0   -0.675392
#  dtype: float64, 0   -0.684459
#  dtype: float64, 0    0.276081
#  dtype: float64, 0   -1.180347
#  dtype: float64, 0   -0.96332
#  dtype: float64, 0   -0.553308
#  dtype: float64, 0   -0.742882
#  dtype: float64, 0   -1.120702
#  dtype: float64, 0    0.765399
#  dtype: float64, 0    0.256005
#  dtype: float64, 0    1.842289
#  dtype: float64, 0   -0.699286
#  dtype: float64, 0   -0.158182
#  dtype: float64, 0   -0.233436
#  dtype: float64, 0   -0.366285
#  dtype: float64, 0   -0.526711
#  dtype: float64, 0   -0.923718
#  dtype: float64, 0    0.452913
#  dtype: float64, 0   -2.007389
#  dtype: float64, 0    1.695496
#  dtype: float64, 0    1.590671
#  dtype: float64, 0   -0.37192
#  dtype: float64, 0    0.123757
#  dtype: float64, 0   -0.063555
#  dtype: float64, 0   -0.393616
#  dtype: float64, 0    0.19316
#  dtype: float64, 0   -0.544571
#  dtype: float64, 0    0.714402
#  dtype: float64, 0   -0.42871
#  dtype: float64, 0    0.184512
#  dtype: float64, 0   -1.992794
#  dtype: float64, 0    0.231305
#  dtype: float64, 0   -2.030558
#  dtype: float64, 0   -0.076142
#  dtype: float64, 0    0.246661
#  dtype: float64, 0    1.128454
#  dtype: float64, 0   -0.090849
#  dtype: float64, 0    1.094337
#  dtype: float64, 0    0.483091
#  dtype: float64, 0    0.525053
#  dtype: float64, 0    0.07937
#  dtype: float64, 0   -0.758371
#  dtype: float64, 0   -1.206512
#  dtype: float64, 0   -0.277397
#  dtype: float64, 0    0.097387
#  dtype: float64, 0   -0.94138
#  dtype: float64, 0   -0.699245
#  dtype: float64, 0    0.247577
#  dtype: float64, 0   -0.355672
#  dtype: float64, 0   -0.609625
#  dtype: float64, 0    0.56951
#  dtype: float64, 0   -0.480102
#  dtype: float64, 0    0.55258
#  dtype: float64, 0   -0.9536
#  dtype: float64, 0   -1.882609
#  dtype: float64, 0   -1.817667
#  dtype: float64, 0   -0.968086
#  dtype: float64, 0   -0.425538
#  dtype: float64, 0    1.408285
#  dtype: float64, 0   -0.938123
#  dtype: float64, 0    1.20716
#  dtype: float64, 0   -0.471217
#  dtype: float64, 0    1.08704
#  dtype: float64, 0   -0.627644
#  dtype: float64, 0    0.833651
#  dtype: float64, 0    0.399673
#  dtype: float64, 0   -0.567984
#  dtype: float64, 0    0.855
#  dtype: float64, 0    1.728503
#  dtype: float64, 0    0.952597
#  dtype: float64, 0    0.446793
#  dtype: float64, 0    1.410387
#  dtype: float64, 0   -0.015749
#  dtype: float64, 0   -0.274833
#  dtype: float64, 0    0.436279
#  dtype: float64, 0   -0.137062
#  dtype: float64, 0   -0.471071
#  dtype: float64, 0   -1.117031
#  dtype: float64, 0    1.986733
#  dtype: float64, 0    0.276306
#  dtype: float64, 0    0.05893
#  dtype: float64, 0   -0.649713
#  dtype: float64, 0    0.780892
#  dtype: float64, 0    0.244723
#  dtype: float64, 0    0.486487
#  dtype: float64, 0   -0.592933
#  dtype: float64, 0    0.876289
#  dtype: float64, 0    0.432613
#  dtype: float64, 0    0.768975
#  dtype: float64, 0   -0.459397
#  dtype: float64, 0    0.561733
#  dtype: float64, 0   -1.814857
#  dtype: float64, 0    1.389864
#  dtype: float64, 0   -1.110466
#  dtype: float64, 0   -2.452202
#  dtype: float64, 0    0.511103
#  dtype: float64, 0   -0.459187
#  dtype: float64, 0    0.007075
#  dtype: float64, 0   -0.661427
#  dtype: float64, 0   -0.008526
#  dtype: float64, 0   -1.43536
#  dtype: float64, 0   -0.411188
#  dtype: float64, 0   -0.22489
#  dtype: float64, 0    1.49222
#  dtype: float64, 0    0.236599
#  dtype: float64, 0    1.072066
#  dtype: float64, 0   -1.453504
#  dtype: float64, 0   -0.150498
#  dtype: float64, 0    1.972475
#  dtype: float64, 0   -0.212259
#  dtype: float64, 0   -1.341167
#  dtype: float64, 0   -0.811091
#  dtype: float64, 0    2.092111
#  dtype: float64, 0   -1.101628
#  dtype: float64, 0   -0.622395
#  dtype: float64, 0   -0.040742
#  dtype: float64, 0   -1.270251
#  dtype: float64, 0    0.860108
#  dtype: float64, 0    1.973529
#  dtype: float64, 0    0.293726
#  dtype: float64, 0    2.080633
#  dtype: float64, 0   -0.366024
#  dtype: float64, 0   -1.001458
#  dtype: float64, 0    0.244297
#  dtype: float64, 0   -1.486503
#  dtype: float64, 0   -0.033994
#  dtype: float64, 0    0.753667
#  dtype: float64, 0    0.050063
#  dtype: float64, 0    0.694266
#  dtype: float64, 0   -1.385623
#  dtype: float64, 0   -0.389056
#  dtype: float64, 0    0.422377
#  dtype: float64, 0    1.263241
#  dtype: float64, 0   -1.898331
#  dtype: float64, 0   -1.004364
#  dtype: float64, 0   -0.453218
#  dtype: float64, 0    1.379575
#  dtype: float64, 0    1.03161
#  dtype: float64, 0   -0.069641
#  dtype: float64, 0   -0.974072
#  dtype: float64, 0   -0.268066
#  dtype: float64, 0   -0.793627
#  dtype: float64, 0   -0.068535
#  dtype: float64, 0    0.429405
#  dtype: float64, 0    0.173183
#  dtype: float64, 0    2.127801
#  dtype: float64, 0   -0.831496
#  dtype: float64, 0   -0.261183
#  dtype: float64, 0    1.905056
#  dtype: float64, 0   -1.462097
#  dtype: float64, 0    0.755929
#  dtype: float64, 0    0.491521
#  dtype: float64, 0    0.416211
#  dtype: float64, 0    0.868031
#  dtype: float64, 0    0.12875
#  dtype: float64, 0    0.96652
#  dtype: float64, 0    0.10653
#  dtype: float64, 0    0.77925
#  dtype: float64, 0    1.082862
#  dtype: float64, 0   -0.145593
#  dtype: float64, 0   -0.681916
#  dtype: float64, 0   -0.925228
#  dtype: float64, 0   -1.824833
#  dtype: float64, 0    0.041201
#  dtype: float64, 0    0.833224
#  dtype: float64, 0   -0.776298
#  dtype: float64, 0   -0.201824
#  dtype: float64, 0   -1.180091
#  dtype: float64, 0    1.821662
#  dtype: float64, 0   -2.205428
#  dtype: float64, 0   -0.315141
#  dtype: float64, 0    1.626498
#  dtype: float64, 0   -0.825355
#  dtype: float64, 0   -0.142245
#  dtype: float64, 0   -0.570951
#  dtype: float64, 0   -0.302215
#  dtype: float64, 0    1.62925
#  dtype: float64, 0    0.663892
#  dtype: float64, 0    0.674144
#  dtype: float64, 0   -0.993343
#  dtype: float64, 0   -1.142598
#  dtype: float64, 0    0.61149
#  dtype: float64, 0    0.530837
#  dtype: float64, 0    0.37192
#  dtype: float64, 0    1.270575
#  dtype: float64, 0   -0.506161
#  dtype: float64, 0   -0.443271
#  dtype: float64, 0   -0.559552
#  dtype: float64, 0   -0.132115
#  dtype: float64, 0    2.040803
#  dtype: float64, 0    0.116878
#  dtype: float64, 0    0.733213
#  dtype: float64, 0    0.01724
#  dtype: float64, 0    1.302556
#  dtype: float64, 0   -1.52386
#  dtype: float64, 0   -1.21385
#  dtype: float64, 0    0.933486
#  dtype: float64, 0   -0.159519
#  dtype: float64, 0   -0.249441
#  dtype: float64, 0    1.679155
#  dtype: float64, 0    1.212777
#  dtype: float64, 0   -1.223604
#  dtype: float64, 0   -1.472124
#  dtype: float64, 0   -0.270215
#  dtype: float64, 0    0.160304
#  dtype: float64, 0    1.541662
#  dtype: float64, 0    0.19765
#  dtype: float64, 0   -0.077069
#  dtype: float64, 0    1.134577
#  dtype: float64, 0   -1.879184
#  dtype: float64, 0    1.534124
#  dtype: float64, 0   -0.004426
#  dtype: float64, 0    0.13383
#  dtype: float64, 0    0.66685
#  dtype: float64, 0    0.331028
#  dtype: float64, 0    1.228112
#  dtype: float64, 0    0.629967
#  dtype: float64, 0    2.008175
#  dtype: float64, 0    0.054239
#  dtype: float64, 0    0.088383
#  dtype: float64, 0    0.222234
#  dtype: float64, 0   -0.383479
#  dtype: float64, 0    0.458626
#  dtype: float64, 0    0.272121
#  dtype: float64, 0   -0.770982
#  dtype: float64, 0    0.525637
#  dtype: float64, 0   -3.157271
#  dtype: float64, 0    1.141152
#  dtype: float64, 0    0.471321
#  dtype: float64, 0    0.282846
#  dtype: float64, 0   -0.54986
#  dtype: float64, 0   -0.089737
#  dtype: float64, 0    0.238492
#  dtype: float64, 0    2.793389
#  dtype: float64, 0    0.025089
#  dtype: float64, 0    1.189795
#  dtype: float64, 0    1.087881
#  dtype: float64, 0    1.143578
#  dtype: float64, 0   -0.337013
#  dtype: float64, 0   -0.376783
#  dtype: float64, 0   -0.598686
#  dtype: float64, 0    0.969554
#  dtype: float64, 0   -0.372835
#  dtype: float64, 0   -1.007121
#  dtype: float64, 0    0.017916
#  dtype: float64, 0   -0.356928
#  dtype: float64, 0    0.132818
#  dtype: float64, 0    0.618364
#  dtype: float64, 0    1.357983
#  dtype: float64, 0   -0.035597
#  dtype: float64, 0    0.801545
#  dtype: float64, 0   -0.276939
#  dtype: float64, 0    0.137433
#  dtype: float64, 0   -0.307511
#  dtype: float64, 0    0.606857
#  dtype: float64, 0    1.002482
#  dtype: float64, 0   -0.618523
#  dtype: float64, 0    0.579864
#  dtype: float64, 0    0.085897
#  dtype: float64, 0   -0.767156
#  dtype: float64, 0    0.487629
#  dtype: float64, 0   -0.53524
#  dtype: float64, 0   -0.491958
#  dtype: float64, 0    1.430776
#  dtype: float64, 0    0.932864
#  dtype: float64, 0    1.46829
#  dtype: float64, 0   -0.767562
#  dtype: float64, 0   -0.972509
#  dtype: float64, 0    1.138319
#  dtype: float64, 0    1.626222
#  dtype: float64, 0    1.21342
#  dtype: float64, 0    2.31609
#  dtype: float64, 0    1.171396
#  dtype: float64, 0    1.232484
#  dtype: float64, 0   -0.636196
#  dtype: float64, 0    0.326162
#  dtype: float64, 0    1.53539
#  dtype: float64, 0   -0.595748
#  dtype: float64, 0   -0.971473
#  dtype: float64, 0    1.047362
#  dtype: float64, 0   -0.19688
#  dtype: float64, 0    1.251805
#  dtype: float64, 0   -0.566909
#  dtype: float64, 0   -1.057915
#  dtype: float64, 0   -0.524684
#  dtype: float64, 0   -2.156896
#  dtype: float64, 0   -2.674022
#  dtype: float64, 0    1.413267
#  dtype: float64, 0    0.116024
#  dtype: float64, 0   -0.277561
#  dtype: float64, 0    1.820504
#  dtype: float64, 0    0.520203
#  dtype: float64, 0    0.49009
#  dtype: float64, 0   -0.854375
#  dtype: float64, 0    0.783986
#  dtype: float64, 0   -0.093447
#  dtype: float64, 0    0.079302
#  dtype: float64, 0    0.297322
#  dtype: float64, 0    0.770704
#  dtype: float64, 0   -0.803729
#  dtype: float64, 0    0.761333
#  dtype: float64, 0   -0.764376
#  dtype: float64, 0   -0.477546
#  dtype: float64, 0   -0.152278
#  dtype: float64, 0   -1.241221
#  dtype: float64, 0    1.347026
#  dtype: float64, 0    0.034382
#  dtype: float64, 0    0.090235
#  dtype: float64, 0   -1.186433
#  dtype: float64, 0    1.812048
#  dtype: float64, 0   -0.605209
#  dtype: float64, 0    0.392039
#  dtype: float64, 0   -0.747319
#  dtype: float64, 0   -0.398098
#  dtype: float64, 0    0.194668
#  dtype: float64, 0    0.86999
#  dtype: float64, 0   -2.287161
#  dtype: float64, 0   -0.972663
#  dtype: float64, 0   -0.891248
#  dtype: float64, 0    1.180276
#  dtype: float64, 0   -0.068216
#  dtype: float64, 0   -0.498415
#  dtype: float64, 0   -0.670945
#  dtype: float64, 0   -1.093146
#  dtype: float64, 0    0.068974
#  dtype: float64, 0   -1.679062
#  dtype: float64, 0   -1.595519
#  dtype: float64, 0   -1.076158
#  dtype: float64, 0   -0.530039
#  dtype: float64, 0    1.000867
#  dtype: float64, 0    1.214003
#  dtype: float64, 0    0.225804
#  dtype: float64, 0    0.806015
#  dtype: float64, 0    0.196715
#  dtype: float64, 0   -0.27276
#  dtype: float64, 0    1.95777
#  dtype: float64, 0   -0.426394
#  dtype: float64, 0    0.915679
#  dtype: float64, 0   -1.250032
#  dtype: float64, 0    1.378788
#  dtype: float64, 0    0.330354
#  dtype: float64, 0    0.930681
#  dtype: float64, 0    0.992464
#  dtype: float64, 0   -1.49644
#  dtype: float64, 0    0.023224
#  dtype: float64, 0    0.90613
#  dtype: float64, 0    0.126263
#  dtype: float64, 0   -1.292679
#  dtype: float64, 0    0.359158
#  dtype: float64, 0    0.64677
#  dtype: float64, 0    2.012304
#  dtype: float64, 0    0.59298
#  dtype: float64, 0   -0.547365
#  dtype: float64, 0   -0.372461
#  dtype: float64, 0    0.550094
#  dtype: float64, 0   -1.551204
#  dtype: float64, 0    0.470642
#  dtype: float64, 0   -1.70329
#  dtype: float64, 0   -0.307639
#  dtype: float64, 0   -0.218953
#  dtype: float64, 0   -0.771867
#  dtype: float64, 0   -0.800427
#  dtype: float64, 0    0.189094
#  dtype: float64, 0    0.618138
#  dtype: float64, 0    0.503207
#  dtype: float64, 0    1.133906
#  dtype: float64, 0    0.659586
#  dtype: float64, 0    1.018459
#  dtype: float64, 0    1.724897
#  dtype: float64, 0    0.15096
#  dtype: float64, 0   -0.219141
#  dtype: float64, 0    0.068322
#  dtype: float64, 0   -0.043289
#  dtype: float64, 0    0.730601
#  dtype: float64, 0    1.432337
#  dtype: float64, 0   -1.148252
#  dtype: float64, 0    0.531761
#  dtype: float64, 0    0.772763
#  dtype: float64, 0   -1.072865
#  dtype: float64, 0   -0.88479
#  dtype: float64, 0    1.033117
#  dtype: float64, 0   -0.463027
#  dtype: float64, 0    1.809178
#  dtype: float64, 0    1.561376
#  dtype: float64, 0    0.753108
#  dtype: float64, 0    1.250724
#  dtype: float64, 0    0.85715
#  dtype: float64, 0   -0.018665
#  dtype: float64, 0   -0.358788
#  dtype: float64, 0   -1.465948
#  dtype: float64, 0    0.111836
#  dtype: float64, 0   -2.444246
#  dtype: float64, 0    0.090459
#  dtype: float64, 0   -1.024043
#  dtype: float64, 0    0.905187
#  dtype: float64, 0    0.132601
#  dtype: float64, 0   -0.652261
#  dtype: float64, 0   -0.238218
#  dtype: float64, 0   -0.787608
#  dtype: float64, 0    1.504753
#  dtype: float64, 0    0.568327
#  dtype: float64, 0   -0.99855
#  dtype: float64, 0   -0.059879
#  dtype: float64, 0   -2.255037
#  dtype: float64, 0    0.832479
#  dtype: float64, 0   -1.122085
#  dtype: float64, 0   -0.453259
#  dtype: float64, 0   -0.53066
#  dtype: float64, 0    0.212859
#  dtype: float64, 0   -1.064089
#  dtype: float64, 0   -2.613312
#  dtype: float64, 0    0.413727
#  dtype: float64, 0    0.287437
#  dtype: float64, 0   -0.388443
#  dtype: float64, 0    0.546689
#  dtype: float64, 0    0.886414
#  dtype: float64, 0    1.569326
#  dtype: float64, 0    1.130922
#  dtype: float64, 0    1.079687
#  dtype: float64, 0    0.502534
#  dtype: float64, 0    0.254663
#  dtype: float64, 0   -0.07294
#  dtype: float64, 0    0.850304
#  dtype: float64, 0   -0.891338
#  dtype: float64, 0   -0.219744
#  dtype: float64, 0    0.993935
#  dtype: float64, 0   -1.174792
#  dtype: float64, 0   -0.116458
#  dtype: float64, 0   -0.999992
#  dtype: float64, 0    0.312767
#  dtype: float64, 0    0.080315
#  dtype: float64, 0    0.552332
#  dtype: float64, 0    0.624317
#  dtype: float64, 0    0.860156
#  dtype: float64, 0   -2.093802
#  dtype: float64, 0    0.069662
#  dtype: float64, 0    1.202531
#  dtype: float64, 0    0.847979
#  dtype: float64, 0    0.154604
#  dtype: float64, 0   -1.096414
#  dtype: float64, 0   -1.897702
#  dtype: float64, 0    0.925296
#  dtype: float64, 0   -0.321234
#  dtype: float64, 0   -0.844194
#  dtype: float64, 0    0.144967
#  dtype: float64, 0    1.250868
#  dtype: float64, 0    0.659022
#  dtype: float64, 0   -0.171266
#  dtype: float64, 0    0.285303
#  dtype: float64, 0   -0.150745
#  dtype: float64, 0   -1.539199
#  dtype: float64, 0    0.732474
#  dtype: float64, 0   -0.107265
#  dtype: float64, 0   -0.744132
#  dtype: float64, 0   -0.010716
#  dtype: float64, 0   -1.50021
#  dtype: float64, 0    0.293817
#  dtype: float64, 0    0.559418
#  dtype: float64, 0   -0.035353
#  dtype: float64, 0   -0.074909
#  dtype: float64, 0    0.590756
#  dtype: float64, 0   -0.821277
#  dtype: float64, 0   -0.051098
#  dtype: float64, 0    1.219825
#  dtype: float64, 0    0.295942
#  dtype: float64, 0   -0.566024
#  dtype: float64, 0   -1.363593
#  dtype: float64, 0    0.235692
#  dtype: float64, 0    0.939177
#  dtype: float64, 0   -0.338222
#  dtype: float64, 0   -0.095469
#  dtype: float64, 0    1.858827
#  dtype: float64, 0    0.23526
#  dtype: float64, 0    1.018477
#  dtype: float64, 0   -0.885241
#  dtype: float64, 0   -1.036888
#  dtype: float64, 0   -0.351304
#  dtype: float64, 0    0.781441
#  dtype: float64, 0   -0.699233
#  dtype: float64, 0    0.862408
#  dtype: float64, 0    0.530735
#  dtype: float64, 0    0.830463
#  dtype: float64, 0   -0.463382
#  dtype: float64, 0   -0.822155
#  dtype: float64, 0    3.106443
#  dtype: float64, 0    0.890117
#  dtype: float64, 0    1.656995
#  dtype: float64, 0   -1.218407
#  dtype: float64, 0    1.774221
#  dtype: float64, 0   -0.932436
#  dtype: float64, 0   -0.730705
#  dtype: float64, 0    1.042439
#  dtype: float64, 0   -1.003879
#  dtype: float64, 0    0.183142
#  dtype: float64, 0    0.54083
#  dtype: float64, 0   -1.476128
#  dtype: float64, 0    0.037681
#  dtype: float64, 0    1.514048
#  dtype: float64, 0    2.422403
#  dtype: float64, 0   -0.724369
#  dtype: float64, 0   -0.842307
#  dtype: float64, 0    0.099819
#  dtype: float64, 0    0.461571
#  dtype: float64, 0   -0.172985
#  dtype: float64, 0   -0.213179
#  dtype: float64, 0    0.151252
#  dtype: float64, 0    1.54644
#  dtype: float64, 0   -1.403021
#  dtype: float64, 0    0.39553
#  dtype: float64, 0    0.304174
#  dtype: float64, 0    0.5296
#  dtype: float64, 0   -1.094475
#  dtype: float64, 0    1.473574
#  dtype: float64, 0    0.891939
#  dtype: float64, 0   -0.504986
#  dtype: float64, 0   -0.226598
#  dtype: float64, 0   -0.239775
#  dtype: float64, 0    1.942856
#  dtype: float64, 0    0.303676
#  dtype: float64, 0   -1.48577
#  dtype: float64, 0    0.020575
#  dtype: float64, 0   -0.309039
#  dtype: float64, 0   -0.956635
#  dtype: float64, 0    0.428245
#  dtype: float64, 0   -0.216929
#  dtype: float64, 0   -0.814434
#  dtype: float64, 0    0.524861
#  dtype: float64, 0   -1.622851
#  dtype: float64, 0    0.351171
#  dtype: float64, 0    1.252072
#  dtype: float64, 0   -2.146549
#  dtype: float64, 0    1.311424
#  dtype: float64, 0   -0.046124
#  dtype: float64, 0   -1.014423
#  dtype: float64, 0   -0.451512
#  dtype: float64, 0   -0.390338
#  dtype: float64, 0   -0.031687
#  dtype: float64, 0    0.160716
#  dtype: float64, 0   -0.449338
#  dtype: float64, 0   -0.519875
#  dtype: float64, 0   -0.982998
#  dtype: float64, 0   -1.155841
#  dtype: float64, 0    0.617535
#  dtype: float64, 0    0.673356
#  dtype: float64, 0    0.967921
#  dtype: float64, 0   -0.569698
#  dtype: float64, 0    2.669266
#  dtype: float64, 0   -0.753038
#  dtype: float64, 0    0.0751
#  dtype: float64, 0   -1.279656
#  dtype: float64, 0    0.498806
#  dtype: float64, 0    0.658526
#  dtype: float64, 0   -0.765859
#  dtype: float64, 0   -0.152893
#  dtype: float64, 0   -1.089319
#  dtype: float64, 0   -0.196839
#  dtype: float64, 0   -0.838378
#  dtype: float64, 0   -0.52435
#  dtype: float64, 0   -1.087395
#  dtype: float64, 0    0.391826
#  dtype: float64, 0    0.173705
#  dtype: float64, 0   -0.752385
#  dtype: float64, 0    0.991665
#  dtype: float64, 0   -1.279204
#  dtype: float64, 0    1.083758
#  dtype: float64, 0   -0.591012
#  dtype: float64, 0   -1.358177
#  dtype: float64, 0   -1.665742
#  dtype: float64, 0   -1.289402
#  dtype: float64, 0   -0.88552
#  dtype: float64, 0   -0.008948
#  dtype: float64, 0    0.680481
#  dtype: float64, 0    0.569733
#  dtype: float64, 0   -0.301068
#  dtype: float64, 0    0.304247
#  dtype: float64, 0   -0.735007
#  dtype: float64, 0    0.351717
#  dtype: float64, 0   -0.519683
#  dtype: float64, 0   -0.141035
#  dtype: float64, 0    0.205167
#  dtype: float64, 0   -1.12845
#  dtype: float64, 0    1.458158
#  dtype: float64, 0   -1.504575
#  dtype: float64, 0    0.140216
#  dtype: float64, 0   -1.036129
#  dtype: float64, 0    1.090507
#  dtype: float64, 0   -2.647369
#  dtype: float64, 0   -0.375135
#  dtype: float64, 0   -1.300624
#  dtype: float64, 0    0.06116
#  dtype: float64, 0   -0.518738
#  dtype: float64, 0   -0.53931
#  dtype: float64, 0   -1.278305
#  dtype: float64, 0   -0.501099
#  dtype: float64, 0   -0.732641
#  dtype: float64, 0   -1.18482
#  dtype: float64, 0   -0.022206
#  dtype: float64, 0    0.366784
#  dtype: float64, 0   -0.207544
#  dtype: float64, 0   -0.08135
#  dtype: float64, 0   -0.321793
#  dtype: float64, 0    0.699546
#  dtype: float64, 0    1.21795
#  dtype: float64, 0   -1.919136
#  dtype: float64, 0   -1.331005
#  dtype: float64, 0    0.000465
#  dtype: float64, 0    0.527397
#  dtype: float64, 0    0.480025
#  dtype: float64, 0   -0.807534
#  dtype: float64, 0    1.684946
#  dtype: float64, 0    0.807392
#  dtype: float64, 0    0.448249
#  dtype: float64, 0    2.537145
#  dtype: float64, 0   -1.849378
#  dtype: float64, 0   -1.963057
#  dtype: float64, 0   -2.352137
#  dtype: float64, 0   -0.998307
#  dtype: float64, 0   -0.877179
#  dtype: float64, 0    0.80159
#  dtype: float64, 0   -0.002808
#  dtype: float64, 0    0.521583
#  dtype: float64, 0   -1.05577
#  dtype: float64, 0    0.841343
#  dtype: float64, 0    2.028895
#  dtype: float64, 0   -0.391236
#  dtype: float64, 0   -1.088972
#  dtype: float64, 0    1.012746
#  dtype: float64, 0    0.161164
#  dtype: float64, 0    0.634282
#  dtype: float64, 0    1.188039
#  dtype: float64, 0    0.027406
#  dtype: float64, 0    0.251324
#  dtype: float64, 0   -0.801406
#  dtype: float64, 0   -0.292146
#  dtype: float64, 0   -0.446086
#  dtype: float64, 0   -0.213162
#  dtype: float64, 0   -0.425826
#  dtype: float64, 0    1.387882
#  dtype: float64, ...]

# %%
# Give your solution here 
sns.distplot(data)
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Your observations
#

# %% [markdown]
# ## Summary
#
# In this lab, you practiced your knowledge on the standard normal distribution!
